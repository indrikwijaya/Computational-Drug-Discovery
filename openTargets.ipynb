# %%
#!/usr/bin/env python3

# Import relevant libraries for HTTP request and JSON formatting
import requests
import json

# Set gene_id variable
gene_id = "ENSG00000169083"

# Build query string
query_string = """
  query target($ensemblId: String!){
    target(ensemblId: $ensemblId){
      id
      approvedSymbol
      biotype
      geneticConstraint {
        constraintType
        exp
        obs
        score
        oe
        oeLower
        oeUpper
      }
      tractability {
        id
        modality
        value
      }
    }
  }
"""

# Set variables object of arguments to be passed to endpoint
variables = {"ensemblId": gene_id}

# Set base URL of GraphQL API endpoint
base_url = "https://api.platform.opentargets.org/api/v4/graphql"

# Perform POST request and check status code of response
r = requests.post(base_url, json={"query": query_string, "variables": variables})
print(r.status_code)

# Transform API response into JSON 
api_response_as_json = json.loads(r.text)

# Print API response to terminal
print(api_response_as_json)
# Out:
# 200
# {'data': {'target': {'id': 'ENSG00000169083', 'approvedSymbol': 'AR', 'biotype': 'protein_coding', 'geneticConstraint': [{'constraintType': 'syn', 'exp': 146.12, 'obs': 159, 'score': -0.83775, 'oe': 1.0882, 'oeLower': 0.956, 'oeUpper': 1.241}, {'constraintType': 'mis', 'exp': 350.67, 'obs': 286, 'score': 1.2272, 'oe': 0.81558, 'oeLower': 0.74, 'oeUpper': 0.899}, {'constraintType': 'lof', 'exp': 26.657, 'obs': 3, 'score': 0.98837, 'oe': 0.11254, 'oeLower': 0.05, 'oeUpper': 0.291}], 'tractability': [{'id': 'Approved Drug', 'modality': 'SM', 'value': True}, {'id': 'Advanced Clinical', 'modality': 'SM', 'value': False}, {'id': 'Phase 1 Clinical', 'modality': 'SM', 'value': False}, {'id': 'Structure with Ligand', 'modality': 'SM', 'value': True}, {'id': 'High-Quality Ligand', 'modality': 'SM', 'value': True}, {'id': 'High-Quality Pocket', 'modality': 'SM', 'value': True}, {'id': 'Med-Quality Pocket', 'modality': 'SM', 'value': False}, {'id': 'Druggable Family', 'modality': 'SM', 'value': True}, {'id': 'Approved Drug', 'modality': 'AB', 'value': False}, {'id': 'Advanced Clinical', 'modality': 'AB', 'value': False}, {'id': 'Phase 1 Clinical', 'modality': 'AB', 'value': False}, {'id': 'UniProt loc high conf', 'modality': 'AB', 'value': False}, {'id': 'GO CC high conf', 'modality': 'AB', 'value': False}, {'id': 'UniProt loc med conf', 'modality': 'AB', 'value': False}, {'id': 'UniProt SigP or TMHMM', 'modality': 'AB', 'value': False}, {'id': 'GO CC med conf', 'modality': 'AB', 'value': True}, {'id': 'Human Protein Atlas loc', 'modality': 'AB', 'value': False}, {'id': 'Approved Drug', 'modality': 'PR', 'value': False}, {'id': 'Advanced Clinical', 'modality': 'PR', 'value': True}, {'id': 'Phase 1 Clinical', 'modality': 'PR', 'value': False}, {'id': 'Literature', 'modality': 'PR', 'value': True}, {'id': 'UniProt Ubiquitination', 'modality': 'PR', 'value': True}, {'id': 'Database Ubiquitination', 'modality': 'PR', 'value': True}, {'id': 'Half-life Data', 'modality': 'PR', 'value': False}, {'id': 'Small Molecule Binder', 'modality': 'PR', 'value': True}, {'id': 'Approved Drug', 'modality': 'OC', 'value': False}, {'id': 'Advanced Clinical', 'modality': 'OC', 'value': False}, {'id': 'Phase 1 Clinical', 'modality': 'OC', 'value': False}]}}}

# %%
# Import relevant libraries for HTTP request and JSON formatting
import requests
import json

# Set gene_id variable
efo_id = "EFO_0000676"

# Build query string
query_string="""
query search($efoId: String!) {
  disease(efoId:$efoId){
    id
    name
    associatedTargets(
      aggregationFilters:[
        {name:"pathwayTypes", path:"Immune System"}
      ],
      datasources: [
        {id:"chembl", weight:0.0, propagate:true}
        {id:"europepmc", weight:0.0, propagate:true}
        {id:"expression_atlas", weight:0.0, propagate:true}
        {id:"phenodigm", weight:0.0, propagate:true}
      ]
    ){
      count
      rows{
        target{
          id
          approvedSymbol
        }
        score
        datasourceScores{
          id
          score
        }
      }
    }    
  }
}
"""

# Set variables object of arguments to be passed to endpoint
variables = {"efoId": efo_id}

# Set base URL of GraphQL API endpoint
base_url = "https://api.platform.opentargets.org/api/v4/graphql"

# Perform POST request and check status code of response
r = requests.post(base_url, json={"query": query_string, "variables": variables})
print(r.status_code)

# Transform API response into JSON 
api_response_as_json = json.loads(r.text)

# Print API response to terminal
print(api_response_as_json)
# Out:
# 200
# {'data': {'disease': {'id': 'EFO_0000676', 'name': 'psoriasis', 'associatedTargets': {'count': 992, 'rows': [{'target': {'id': 'ENSG00000136695', 'approvedSymbol': 'IL36RN'}, 'score': 0.7468849549430213, 'datasourceScores': [{'id': 'genomics_england', 'score': 0.8897742701710087}, {'id': 'uniprot_variants', 'score': 0.865457038266544}, {'id': 'orphanet', 'score': 0.7599134970145264}, {'id': 'uniprot_literature', 'score': 0.607930797611621}, {'id': 'europepmc', 'score': 0.26814261427974706}, {'id': 'phenodigm', 'score': 0.44681393797460117}, {'id': 'expression_atlas', 'score': 0.26473540144884855}]}, {'target': {'id': 'ENSG00000113302', 'approvedSymbol': 'IL12B'}, 'score': 0.5000154753550079, 'datasourceScores': [{'id': 'ot_genetics_portal', 'score': 0.8212111381955114}, {'id': 'phewas_catalog', 'score': 0.005105404150024377}, {'id': 'chembl', 'score': 0.9616821291005339}, {'id': 'europepmc', 'score': 0.2776549818373325}, {'id': 'expression_atlas', 'score': 0.35130576934316143}]}, {'target': {'id': 'ENSG00000007171', 'approvedSymbol': 'NOS2'}, 'score': 0.4963505121659858, 'datasourceScores': [{'id': 'ot_genetics_portal', 'score': 0.8164589030790989}, {'id': 'europepmc', 'score': 0.2928672710268505}, {'id': 'expression_atlas', 'score': 0.3507737766158057}]}, {'target': {'id': 'ENSG00000164307', 'approvedSymbol': 'ERAP1'}, 'score': 0.4934549780898428, 'datasourceScores': [{'id': 'ot_genetics_portal', 'score': 0.8116959693907273}, {'id': 'europepmc', 'score': 0.5097891849645682}]}, {'target': {'id': 'ENSG00000162924', 'approvedSymbol': 'REL'}, 'score': 0.47583347651481156, 'datasourceScores': [{'id': 'ot_genetics_portal', 'score': 0.7816739226882019}, {'id': 'phewas_catalog', 'score': 0.004144058667484672}, {'id': 'europepmc', 'score': 0.062417321903644886}, {'id': 'expression_atlas', 'score': 0.042421444039017146}]}, {'target': {'id': 'ENSG00000115267', 'approvedSymbol': 'IFIH1'}, 'score': 0.4713827076389324, 'datasourceScores': [{'id': 'ot_genetics_portal', 'score': 0.7753887605149379}, {'id': 'europepmc', 'score': 0.26612074870300834}, {'id': 'expression_atlas', 'score': 0.13961172000071936}]}, {'target': {'id': 'ENSG00000155849', 'approvedSymbol': 'ELMO1'}, 'score': 0.45736752659799496, 'datasourceScores': [{'id': 'ot_genetics_portal', 'score': 0.7523348519187639}, {'id': 'europepmc', 'score': 0.030396539880581056}]}, {'target': {'id': 'ENSG00000204525', 'approvedSymbol': 'HLA-C'}, 'score': 0.4516671910095537, 'datasourceScores': [{'id': 'uniprot_literature', 'score': 0.607930797611621}, {'id': 'ot_genetics_portal', 'score': 0.5361107744667277}, {'id': 'phewas_catalog', 'score': 0.008997673424735737}, {'id': 'europepmc', 'score': 0.8816436830304463}]}, {'target': {'id': 'ENSG00000107201', 'approvedSymbol': 'DDX58'}, 'score': 0.41437727996436113, 'datasourceScores': [{'id': 'ot_genetics_portal', 'score': 0.6816191605892085}, {'id': 'europepmc', 'score': 0.659414514474017}, {'id': 'expression_atlas', 'score': 0.12034373325743072}]}, {'target': {'id': 'ENSG00000169194', 'approvedSymbol': 'IL13'}, 'score': 0.41381602063447875, 'datasourceScores': [{'id': 'ot_genetics_portal', 'score': 0.6806959316097138}, {'id': 'europepmc', 'score': 0.17086630633718228}]}, {'target': {'id': 'ENSG00000100906', 'approvedSymbol': 'NFKBIA'}, 'score': 0.40716442392108315, 'datasourceScores': [{'id': 'ot_genetics_portal', 'score': 0.6697545600925481}, {'id': 'phenodigm', 'score': 0.3788118121717613}, {'id': 'expression_atlas', 'score': 0.03582874724450818}, {'id': 'europepmc', 'score': 0.1849984977444615}]}, {'target': {'id': 'ENSG00000118503', 'approvedSymbol': 'TNFAIP3'}, 'score': 0.4064290493831754, 'datasourceScores': [{'id': 'ot_genetics_portal', 'score': 0.6685449248169595}, {'id': 'europepmc', 'score': 0.8566796799924525}, {'id': 'expression_atlas', 'score': 0.07219716790913233}]}, {'target': {'id': 'ENSG00000181634', 'approvedSymbol': 'TNFSF15'}, 'score': 0.3989313581614132, 'datasourceScores': [{'id': 'ot_genetics_portal', 'score': 0.656211792 ...

# %%
for item in api_response_as_json['data']['disease']:
  print(item)
  if item == 'associatedTargets':
    for keys in api_response_as_json['data']['disease'][item]:
      print(keys)
# Out:
# id
# name
# associatedTargets
# count
# rows
