# %% [markdown]
# This notebook adapts from https://github.com/dataprofessor/bioinformatics_freecodecamp

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      |████████████████████████████████| 55 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 636 kB 19.3 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.0.1 which is incompatible.
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # 1. Downloading data
#
# ## 1.1 Search for target protein
#
# ### Target search for Acetylcholinesterase

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  ...  tax_id
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...  ...    9606
# 1                                                  []  ...    9606
# 2                                                  []  ...    7227
# 3   [{'xref_id': 'P04058', 'xref_name': None, 'xre...  ...    7787
# 4   [{'xref_id': 'P21836', 'xref_name': None, 'xre...  ...   10090
# 5   [{'xref_id': 'P37136', 'xref_name': None, 'xre...  ...   10116
# 6   [{'xref_id': 'O42275', 'xref_name': None, 'xre...  ...    8005
# 7   [{'xref_id': 'P23795', 'xref_name': None, 'xre...  ...    9913
# 8                                                  []  ...    7165
# 9                                                  []  ...    7038
# 10                                                 []  ...    7539
# 11                                                 []  ...   94400
# 12                                                 []  ...    9031
# ...

# %% [markdown]
# ### Select & retrieve bioactivity data for Human Acetylcholinesterase (1st entry)
#
# ---

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL220'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type = 'IC50')

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#      activity_comment  activity_id  ... upper_value  value
# 0                None        33969  ...        None   0.75
# 1                None        37563  ...        None    0.1
# 2                None        37565  ...        None   50.0
# 3                None        38902  ...        None    0.3
# 4                None        41170  ...        None    0.8
# ...               ...          ...  ...         ...    ...
# 7544             None     20703835  ...        None   0.74
# 7545             None     20703856  ...        None   0.51
# 7546             None     20708928  ...        None  125.0
# 7547             None     20708929  ...        None  100.0
# 7548             None     20708930  ...        None    0.1
#
# [7549 rows x 45 columns]

# %%
## save our bioactivity data
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## 1.2 Handling missing data
#
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      activity_comment  activity_id  ... upper_value  value
# 0                None        33969  ...        None   0.75
# 1                None        37563  ...        None    0.1
# 2                None        37565  ...        None   50.0
# 3                None        38902  ...        None    0.3
# 4                None        41170  ...        None    0.8
# ...               ...          ...  ...         ...    ...
# 7544             None     20703835  ...        None   0.74
# 7545             None     20703856  ...        None   0.51
# 7546             None     20708928  ...        None  125.0
# 7547             None     20708929  ...        None  100.0
# 7548             None     20708930  ...        None    0.1
#
# [6340 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 5103

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  ... upper_value  value
# 0                None        33969  ...        None   0.75
# 1                None        37563  ...        None    0.1
# 2                None        37565  ...        None   50.0
# 3                None        38902  ...        None    0.3
# 4                None        41170  ...        None    0.8
# ...               ...          ...  ...         ...    ...
# 7543             None     20703806  ...        None  266.0
# 7544             None     20703835  ...        None   0.74
# 7545             None     20703856  ...        None   0.51
# 7546             None     20708928  ...        None  125.0
# 7547             None     20708929  ...        None  100.0
#
# [5103 rows x 45 columns]

# %% [markdown]
# ## 1.3 Data pre-processing of the bioactivity data
# Combine the 3 columns (molecule_chembl_id, canonical_smiles, standard_value) and bioactivity_class into a DataFrame

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id  ... standard_value
# 0          CHEMBL133897  ...          750.0
# 1          CHEMBL336398  ...          100.0
# 2          CHEMBL131588  ...        50000.0
# 3          CHEMBL130628  ...          300.0
# 4          CHEMBL130478  ...          800.0
# ...                 ...  ...            ...
# 7543      CHEMBL4645476  ...       266000.0
# 7544      CHEMBL4645659  ...          740.0
# 7545       CHEMBL513063  ...          510.0
# 7546      CHEMBL4640608  ...       125000.0
# 7547      CHEMBL4173961  ...       100000.0
#
# [5103 rows x 3 columns]

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index = False)

# %% [markdown]
# ### Labelling compounds as either being active, inactive or intermediate
# The bioactivity data is in the IC50 unit. Compounds having values of < 1000nM will be considered to be **active** while those > 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')
active_thresh = 1000
inactive_thresh = 10000

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= inactive_thresh:
    bioactivity_threshold.append('inactive')
  elif float(i) <= active_thresh:
    bioactivity_threshold.append('active')
  else:
    bioactivity_threshold.append('intermediate')

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name = 'class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id  ...     class
# 0          CHEMBL133897  ...    active
# 1          CHEMBL336398  ...    active
# 2          CHEMBL131588  ...  inactive
# 3          CHEMBL130628  ...    active
# 4          CHEMBL130478  ...    active
# ...                 ...  ...       ...
# 5098      CHEMBL4645476  ...  inactive
# 5099      CHEMBL4645659  ...    active
# 5100       CHEMBL513063  ...    active
# 5101      CHEMBL4640608  ...  inactive
# 5102      CHEMBL4173961  ...  inactive
#
# [5103 rows x 4 columns]

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
# !zip acetylcholinesterase.zip *csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 91%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 5076
# -rw-r--r-- 1 root root 3870914 Oct 12 03:21 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  374458 Oct 12 03:21 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  421009 Oct 12 03:21 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  516614 Oct 12 03:21 acetylcholinesterase.zip
# drwxr-xr-x 1 root root    4096 Oct  8 13:45 sample_data

# %% [markdown]
# # 2. Exploratory Data Analysis

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2021-10-12 03:21:43--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   144MB/s    in 0.6s
#
# 2021-10-12 03:21:44 (144 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %% [markdown]
# ## 2.1 Load Bioactivity data

# %%
df = pd.read_csv('acetylcholinesterase_03_bioactivity_data_curated.csv')
df
# Out:
#      molecule_chembl_id  ...     class
# 0          CHEMBL133897  ...    active
# 1          CHEMBL336398  ...    active
# 2          CHEMBL131588  ...  inactive
# 3          CHEMBL130628  ...    active
# 4          CHEMBL130478  ...    active
# ...                 ...  ...       ...
# 5098      CHEMBL4645476  ...  inactive
# 5099      CHEMBL4645659  ...    active
# 5100       CHEMBL513063  ...    active
# 5101      CHEMBL4640608  ...  inactive
# 5102      CHEMBL4173961  ...  inactive
#
# [5103 rows x 4 columns]

# %%
df_no_smiles = df.drop(columns = 'canonical_smiles')

# %%
smiles = []
for i in df.canonical_smiles.tolist():
  cpd = str(i).split('.')
  cpd_longest = max(cpd, key = len)
  smiles.append(cpd_longest)

smiles = pd.Series(smiles, name = 'canonical_smiles')

# %%
df_clean_smiles = pd.concat([df_no_smiles, smiles], axis=1)
df_clean_smiles
# Out:
#      molecule_chembl_id  ...                                   canonical_smiles
# 0          CHEMBL133897  ...              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398  ...         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  ...  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628  ...      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478  ...          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...  ...                                                ...
# 5098      CHEMBL4645476  ...                CN(C)C(=O)Oc1ccc(C(O)CNC2CCCCC2)cc1
# 5099      CHEMBL4645659  ...   COc1ccc(CCC(=O)Nc2nc(-c3cc4ccccc4oc3=O)cs2)cc1OC
# 5100       CHEMBL513063  ...              COc1ccc(-c2csc(NC(=O)CCN3CCCC3)n2)cc1
# 5101      CHEMBL4640608  ...  COc1cc(C2C3=C(CCCC3=O)NC3=C2C(=O)CCC3)ccc1OCc1...
# 5102      CHEMBL4173961  ...  O=C1CCCC2=C1C(c1ccc(OCc3cccc(F)c3)c(Br)c1)C1=C...
#
# ...

# %% [markdown]
# ## 2.2 Calculate Lipinski descriptores
# **Druglikeness** according to Christopher Lipinski, based on the Absorption, Distribution, Metabolism and Excretion (ADME), also known as the pharmacokinetic profile.
#
# Lipinski's Rule stated the following:
# 1. Molecular weight < 500 Da
# 2. Octanol-water partition coefficient (logP) < 5
# 3. Hydrogen bond donors < 5
# 4. Hydrogen bond acceptors < 10

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %% [markdown]
# ### Calculate descriptors

# %%
# Inspired by: https://codeocean.com/explore/capsules?query=tag:data-curation

def lipinski(smiles, verbose=False):
  moldata = []
  for elem in smiles:
    mol = Chem.MolFromSmiles(elem)
    moldata.append(mol)
  
  baseData = np.arange(1, 1)
  i = 0
  for mol in moldata:
    desc_MolWt = Descriptors.MolWt(mol)
    desc_MolLogP = Descriptors.MolLogP(mol)
    desc_NumHDonors = Lipinski.NumHDonors(mol)
    desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)

    row = np.array([desc_MolWt,
                    desc_MolLogP,
                    desc_NumHDonors,
                    desc_NumHAcceptors])
    
    if i == 0:
      baseData = row
    else:
      baseData = np.vstack([baseData, row])
    i += 1
  
  columnNames = ['MW', 'LogP', 'NumHDonors', 'NumHAcceptors']
  descriptors = pd.DataFrame(data = baseData, columns = columnNames)

  return descriptors

# %%
df_lipinski = lipinski(df_clean_smiles.canonical_smiles)
df_lipinski
# Out:
#            MW    LogP  NumHDonors  NumHAcceptors
# 0     312.325  2.8032         0.0            6.0
# 1     376.913  4.5546         0.0            5.0
# 2     426.851  5.3574         0.0            5.0
# 3     404.845  4.7069         0.0            5.0
# 4     346.334  3.0953         0.0            6.0
# ...       ...     ...         ...            ...
# 5098  306.406  2.7027         2.0            4.0
# 5099  436.489  4.5050         1.0            7.0
# 5100  331.441  3.2431         1.0            5.0
# 5101  447.506  5.1143         1.0            5.0
# 5102  496.376  5.8682         1.0            4.0
#
# [5103 rows x 4 columns]

# %%
# Combine the 2 dataframes
df_combined = pd.concat([df, df_lipinski], axis=1)
df_combined
# Out:
#      molecule_chembl_id  ... NumHAcceptors
# 0          CHEMBL133897  ...           6.0
# 1          CHEMBL336398  ...           5.0
# 2          CHEMBL131588  ...           5.0
# 3          CHEMBL130628  ...           5.0
# 4          CHEMBL130478  ...           6.0
# ...                 ...  ...           ...
# 5098      CHEMBL4645476  ...           4.0
# 5099      CHEMBL4645659  ...           7.0
# 5100       CHEMBL513063  ...           5.0
# 5101      CHEMBL4640608  ...           5.0
# 5102      CHEMBL4173961  ...           4.0
#
# [5103 rows x 8 columns]

# %% [markdown]
# ### Convert IC50 to pIC50
# To allow IC50 data to be more uniformly distributed, we should convert this to the -ve logarithmic scale which is essentially **-log10(IC50)**.
#
# We'll create a custom function that'll take a DataFrame as input and will:
# - Take the IC50 values from the standard_value column and converts it from nM to M by multiplying the value by $10^{-9}$
# - Take the molar value and apply -log10
# - Delete the standard_value column and create a new pIC50 column

# %%
# https://github.com/chaninlab/estrogen-receptor-alpha-qsar/blob/master/02_ER_alpha_RO5.ipynb

def pIC50(input):
  pIC50 = []

  for i in input['standard_value_norm']:
    molar = i*(10**-9) # converts nM to M
    pIC50.append(-np.log10(molar))

  input['pIC50'] = pIC50
  x = input.drop('standard_value_norm', 1)

  return x

# %%
# note: values > 10^8 will be fixed at at 10^8 o/w the -ve log value will become -ve
df_combined.standard_value.describe()
# Out:
# count    5.103000e+03
# mean     2.954208e+12
# std      1.141058e+14
# min      5.000000e-06
# 25%      1.240000e+02
# 50%      2.100000e+03
# 75%      1.593000e+04
# max      5.888437e+15
# Name: standard_value, dtype: float64

# %%
def norm_value(input):
  norm = []
  for i in input['standard_value']:
    if i > 10**8:
      i = 10**8
    norm.append(i)
  
  input['standard_value_norm'] = norm
  x = input.drop('standard_value', 1)

  return x

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
#      molecule_chembl_id  ... standard_value_norm
# 0          CHEMBL133897  ...               750.0
# 1          CHEMBL336398  ...               100.0
# 2          CHEMBL131588  ...             50000.0
# 3          CHEMBL130628  ...               300.0
# 4          CHEMBL130478  ...               800.0
# ...                 ...  ...                 ...
# 5098      CHEMBL4645476  ...            266000.0
# 5099      CHEMBL4645659  ...               740.0
# 5100       CHEMBL513063  ...               510.0
# 5101      CHEMBL4640608  ...            125000.0
# 5102      CHEMBL4173961  ...            100000.0
#
# [5103 rows x 8 columns]

# %%
df_norm.standard_value_norm.describe()
# Out:
# count    5.103000e+03
# mean     3.034241e+05
# std      4.526582e+06
# min      5.000000e-06
# 25%      1.240000e+02
# 50%      2.100000e+03
# 75%      1.593000e+04
# max      1.000000e+08
# Name: standard_value_norm, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final
# Out:
#      molecule_chembl_id  ...     pIC50
# 0          CHEMBL133897  ...  6.124939
# 1          CHEMBL336398  ...  7.000000
# 2          CHEMBL131588  ...  4.301030
# 3          CHEMBL130628  ...  6.522879
# 4          CHEMBL130478  ...  6.096910
# ...                 ...  ...       ...
# 5098      CHEMBL4645476  ...  3.575118
# 5099      CHEMBL4645659  ...  6.130768
# 5100       CHEMBL513063  ...  6.292430
# 5101      CHEMBL4640608  ...  3.903090
# 5102      CHEMBL4173961  ...  4.000000
#
# [5103 rows x 8 columns]

# %%
df_final.pIC50.describe()
# Out:
# count    5103.000000
# mean        5.856468
# std         1.611848
# min         1.000000
# 25%         4.797788
# 50%         5.677781
# 75%         6.906592
# max        14.301030
# Name: pIC50, dtype: float64

# %%
df_final.to_csv('acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv')

# %% [markdown]
# ### Removing the 'intermediate' bioactivity class

# %%
df_2class = df_final[df_final['class'] != 'intermediate']
df_2class
# Out:
#      molecule_chembl_id  ...     pIC50
# 0          CHEMBL133897  ...  6.124939
# 1          CHEMBL336398  ...  7.000000
# 2          CHEMBL131588  ...  4.301030
# 3          CHEMBL130628  ...  6.522879
# 4          CHEMBL130478  ...  6.096910
# ...                 ...  ...       ...
# 5098      CHEMBL4645476  ...  3.575118
# 5099      CHEMBL4645659  ...  6.130768
# 5100       CHEMBL513063  ...  6.292430
# 5101      CHEMBL4640608  ...  3.903090
# 5102      CHEMBL4173961  ...  4.000000
#
# [3863 rows x 8 columns]

# %%
df_2class.to_csv('acetylcholinesterase_05_bioactivity_data_2class_pIC50.csv')

# %% [markdown]
# ## 2.2 Exploratory Data Analysis (Chemical Space Analysis) via Lipinski Descriptors

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %% [markdown]
# ### Frequency plot of 2 bioactivity classes

# %%
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='class', data=df_2class, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot_bioactivity_class.pdf')

# %% [markdown]
# ### Scatter plot of MW vs LogP
#
# It can be seen that the 2 bioactivity classes are spanning similar chemical spaces as evident by the scatter plot of MW vs LogP

# %%
plt.figure(figsize=(5.5, 5.5))

sns.scatterplot(x = 'MW', y = 'LogP', data=df_2class, hue='class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %% [markdown]
# ### Boxplot

# %%
def plot_boxplot(descriptor, name):
  plt.figure(figsize=(5.5, 5.5))
  sns.boxplot(x = 'class', y = 'pIC50', data = df_2class)

  plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
  plt.ylabel(descriptor, fontsize=14, fontweight='bold')

  plt.savefig('plot_' + name + '.pdf')


# pIC50 value

plot_boxplot('pIC50 value', 'ic50')

# %% [markdown]
# ### Statistical analysis | Mann-Whitney U Test

# %%
def mannwhitney(descriptor, alpha, verbose=False):
  # https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/

  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

  seed(1)

  # actives & inactives
  selection = [descriptor, 'class']
  df = df_2class[selection]
  active = df[df['class'] == 'active']
  active = active[descriptor]

  inactive = df[df['class'] == 'inactive']
  inactive = inactive[descriptor]

  # compare samples
  stat, p = mannwhitneyu(active, inactive)
  print('Statistics = %.3f, p=%.3f' % (stat, p))

  if p > alpha:
    interpret = 'Same distribution (fail to reject H0)'
  else:
    interpret = 'Different distribution (reject H0)'
  
  results = pd.DataFrame({'Descriptor': descriptor,
                          'Statistics': stat,
                          'p': p,
                          'alpha': alpha,
                          'Interpretation': interpret}, index=[0])
  
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50', 0.05)
# Out:
# Statistics = 0.000, p=0.000
#   Descriptor  Statistics    p  alpha                      Interpretation
# 0      pIC50         0.0  0.0   0.05  Different distribution (reject H0)

# %%
plot_boxplot('MW', 'MW')

# %%
mannwhitney('MW', 0.05)
# Out:
# Statistics = 1260533.000, p=0.000
#   Descriptor  Statistics  ...  alpha                      Interpretation
# 0         MW   1260533.0  ...   0.05  Different distribution (reject H0)
#
# [1 rows x 5 columns]

# %%
plot_boxplot('LogP', 'LogP')

# %%
mannwhitney('LogP', 0.05)
# Out:
# Statistics = 1210850.500, p=0.000
#   Descriptor  Statistics  ...  alpha                      Interpretation
# 0       LogP   1210850.5  ...   0.05  Different distribution (reject H0)
#
# [1 rows x 5 columns]

# %%
plot_boxplot('NumHDonors', 'NumHDonors')

# %%
mannwhitney('NumHDonors', 0.05)
# Out:
# Statistics = 1569410.000, p=0.000
#    Descriptor  Statistics  ...  alpha                      Interpretation
# 0  NumHDonors   1569410.0  ...   0.05  Different distribution (reject H0)
#
# [1 rows x 5 columns]

# %%
plot_boxplot('NumHAcceptors', 'NumHAcceptors')

# %%
mannwhitney('NumHAcceptors', 0.05)
# Out:
# Statistics = 1702201.500, p=0.000
#       Descriptor  Statistics  ...  alpha                      Interpretation
# 0  NumHAcceptors   1702201.5  ...   0.05  Different distribution (reject H0)
#
# [1 rows x 5 columns]

# %% [markdown]
# ## 2.3 Interpretation of Stats Results
#
# **pIC50 values**
#
# Taking a look at pIC50 values, the **actives** and **inactives** displayed **statistically significant difference**, which is to be expected since threshold values (IC50 < 1,000 nM = Actives while IC50 > 10,000 nM = Inactives, corresponding to pIC50 > 6 = Actives and pIC50 < 5 = Inactives) were used to define actives and inactives.
#
# **Lipinski's descriptors**
# All of the 4 Lipinski's descriptors exhibited **statistially significant difference** between the **actives** and **inactives**

# %%
! zip -r results.zip . -i *.csv *.pdf
# Out:
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: plot_NumHAcceptors.pdf (deflated 37%)
#   adding: acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv (deflated 76%)
#   adding: mannwhitneyu_NumHAcceptors.csv (deflated 13%)
#   adding: mannwhitneyu_MW.csv (deflated 10%)
#   adding: plot_NumHDonors.pdf (deflated 37%)
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 91%)
#   adding: plot_bioactivity_class.pdf (deflated 39%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 82%)
#   adding: plot_MW_vs_LogP.pdf (deflated 2%)
#   adding: mannwhitneyu_pIC50.csv (deflated 14%)
#   adding: mannwhitneyu_NumHDonors.csv (deflated 11%)
#   adding: plot_ic50.pdf (deflated 36%)
#   adding: acetylcholinesterase_05_bioactivity_data_2class_pIC50.csv (deflated 76%)
#   adding: plot_LogP.pdf (deflated 37%)
#   adding: plot_MW.pdf (deflated 38%)
#   adding: mannwhitneyu_LogP.csv (deflated 9%)

# %% [markdown]
# # 3. Descriptor Calculation and Dataset Preparation

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2021-10-12 03:23:10--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2021-10-12 03:23:10--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M   134MB/s    in 0.2s
#
# 2021-10-12 03:23:10 (134 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# ...

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
# ...

# %%
df3 = pd.read_csv('acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv')

# %%
df3
# Out:
#       Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0              0       CHEMBL133897  ...           6.0  6.124939
# 1              1       CHEMBL336398  ...           5.0  7.000000
# 2              2       CHEMBL131588  ...           5.0  4.301030
# 3              3       CHEMBL130628  ...           5.0  6.522879
# 4              4       CHEMBL130478  ...           6.0  6.096910
# ...          ...                ...  ...           ...       ...
# 5098        5098      CHEMBL4645476  ...           4.0  3.575118
# 5099        5099      CHEMBL4645659  ...           7.0  6.130768
# 5100        5100       CHEMBL513063  ...           5.0  6.292430
# 5101        5101      CHEMBL4640608  ...           5.0  3.903090
# 5102        5102      CHEMBL4173961  ...           4.0  4.000000
#
# [5103 rows x 9 columns]

# %%
selection = ['canonical_smiles', 'molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
# !cat molecule.smi | head -5
! cat molecule.smi | wc -l
# Out:
# CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1	CHEMBL133897
# O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1	CHEMBL336398
# CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1	CHEMBL131588
# O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F	CHEMBL130628
# CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C	CHEMBL130478
# 5103

# %% [markdown]
# ## 3.1 Calculate fingerprint descriptors
#
# ### Calculate PaDEL descriptors

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing CHEMBL132133 in molecule.smi (104/5103). Average speed: 0.27 s/mol.
# Processing CHEMBL134382 in molecule.smi (107/5103). Average speed: 0.27 s/mol.
# Processing CHEMBL134488 in molecule.smi (106/5103). Average speed: 0.27 s/mol.
# Processing CHEMBL59109 in molecule.smi (108/5103). Average speed: 0.27 s/mol.
# Processing CHEMBL286990 in molecule.smi (109/5103). Average speed: 0.27 s/mol.
# Processing CHEMBL294891 in molecule.smi (110/5103). Average speed: 0.26 s/mol.
# Processing CHEMBL89011 in molecule.smi (112/5103). Average speed: 0.26 s/mol.
# Processing CHEMBL1255901 in molecule.smi (111/5103). Average speed: 0.26 s/mol.
# Processing CHEMBL748 in molecule.smi (113/5103). Average speed: 0.26 s/mol.
# Processing CHEMBL50608 in molecule.smi (114/5103). Average speed: 0.26 s/mol.
# Processing CHEMBL29300 in molecule.smi (115/5103). Average speed: 0.26 s/mol.
# ...

# %% [markdown]
# ## 3.2 Preparing feature and label matrices

# %%
df3_X = pd.read_csv('descriptors_output.csv')

# %%
df3_X
# Out:
#                Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0      CHEMBL336398           1  ...             0             0
# 1      CHEMBL133897           1  ...             0             0
# 2      CHEMBL131588           1  ...             0             0
# 3      CHEMBL130628           1  ...             0             0
# 4      CHEMBL130478           1  ...             0             0
# ...             ...         ...  ...           ...           ...
# 5098  CHEMBL4638958           1  ...             0             0
# 5099   CHEMBL513063           1  ...             0             0
# 5100  CHEMBL4645659           1  ...             0             0
# 5101  CHEMBL4640608           1  ...             0             0
# 5102  CHEMBL4173961           1  ...             0             0
#
# [5103 rows x 882 columns]

# %%
df3_X = df3_X.drop(columns = ['Name'])
df3_X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 5098           1           1  ...             0             0
# 5099           1           1  ...             0             0
# 5100           1           1  ...             0             0
# 5101           1           1  ...             0             0
# 5102           1           1  ...             0             0
#
# [5103 rows x 881 columns]

# %%
df3_Y = df3['pIC50']
df3_Y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 5098    3.575118
# 5099    6.130768
# 5100    6.292430
# 5101    3.903090
# 5102    4.000000
# Name: pIC50, Length: 5103, dtype: float64

# %%
dataset3 = pd.concat([df3_X, df3_Y], axis=1)
dataset3
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           1  ...             0             0  6.124939
# 1              1           1           1  ...             0             0  7.000000
# 2              1           1           0  ...             0             0  4.301030
# 3              1           1           1  ...             0             0  6.522879
# 4              1           1           0  ...             0             0  6.096910
# ...          ...         ...         ...  ...           ...           ...       ...
# 5098           1           1           1  ...             0             0  3.575118
# 5099           1           1           1  ...             0             0  6.130768
# 5100           1           1           1  ...             0             0  6.292430
# 5101           1           1           1  ...             0             0  3.903090
# ...

# %%
dataset3.to_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv', index=False)

# %% [markdown]
# # 4. Regression models with Random Forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
# Input features
X = df.drop('pIC50', axis=1)
X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 5098           1           1  ...             0             0
# 5099           1           1  ...             0             0
# 5100           1           1  ...             0             0
# 5101           1           1  ...             0             0
# 5102           1           1  ...             0             0
#
# [5103 rows x 881 columns]

# %%
# Output features
Y = df.pIC50
Y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 5098    3.575118
# 5099    6.130768
# 5100    6.292430
# 5101    3.903090
# 5102    4.000000
# Name: pIC50, Length: 5103, dtype: float64

# %%
X.shape
# Out:
# (5103, 881)

# %%
Y.shape
# Out:
# (5103,)

# %% [markdown]
# ### Remove low variance features

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold = (.8 * (1 - .8)))
X = selection.fit_transform(X)

# %%
X.shape
# Out:
# (5103, 140)

# %% [markdown]
# ### Data split to training and test set

# %%
test_size = 0.2
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size)

# %%
X_train.shape, Y_train.shape
# Out:
# ((4082, 140), (4082,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((1021, 140), (1021,))

# %% [markdown]
# ### Build a Regression Model using Random Forest

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2
# Out:
# 0.467012183996845

# %%
Y_pred = model.predict(X_test)

# %%
sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show>

# %% [markdown]
# # 5. Comparing Regressors

# %%
# ! git clone git://github.com/shankarpandala/lazypredict
# % cd lazypredict
# ! python setup.py install
! pip install lazypredict
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 302 kB 40.9 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 12.8 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 34.6 MB/s
# ...
#      |████████████████████████████████| 72 kB 355 kB/s
# ...
#      |████████████████████████████████| 25.9 MB 935 bytes/s
# ...
#      |████████████████████████████████| 127.6 MB 18 kB/s
# ...
#      |████████████████████████████████| 269 kB 35.9 MB/s
# ...
#      |████████████████████████████████| 82 kB 784 kB/s
# ...
#      |████████████████████████████████| 14.5 MB 7.9 kB/s
# ...
#      |████████████████████████████████| 248 kB 43.7 MB/s
# ...
#      |████████████████████████████████| 51 kB 98 kB/s
# ...
#      |████████████████████████████████| 97 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.0 MB/s
# ...
#      |████████████████████████████████| 40 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 67 kB 2.6 MB/s
# ...

# %%
import pandas as pd
import seaborn as sns
#import sklearn
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
import lazypredict

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %%
X.shape
# Out:
# (5103, 881)

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
X = selection.fit_transform(X)
X.shape
# Out:
# (5103, 140)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

# %%
clf = lazypredict.Supervised.LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
models_train, predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test, predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#  95%|█████████▍| 36/38 [01:08<00:04,  2.10s/it]
# [03:46:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# 100%|██████████| 38/38 [00:00<00:00, 206188.29it/s]

# %%
predictions_train
# Out:
#                                         Adjusted R-Squared  ...  Time Taken
# Model                                                       ...
# DecisionTreeRegressor                                 0.86  ...        0.16
# ExtraTreeRegressor                                    0.86  ...        0.18
# ExtraTreesRegressor                                   0.86  ...        6.16
# GaussianProcessRegressor                              0.86  ...        6.59
# RandomForestRegressor                                 0.82  ...        4.87
# BaggingRegressor                                      0.80  ...        0.76
# MLPRegressor                                          0.78  ...        9.74
# HistGradientBoostingRegressor                         0.67  ...        3.39
# LGBMRegressor                                         0.67  ...        0.65
# KNeighborsRegressor                                   0.63  ...        5.47
# ...

# %%
predictions_test
# Out:
# Empty DataFrame
# Columns: [Adjusted R-Squared, R-Squared, RMSE, Time Taken]
# Index: []

# %%
# Bar plot of R-squared values
plt.figure(figsize=(5, 10))
sns.set_theme(style='whitegrid')
ax = sns.barplot(y=predictions_train.index, x='R-Squared', data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
plt.figure(figsize=(5, 10))
sns.set_theme(style='whitegrid')
ax = sns.barplot(y=predictions_train.index, x='RMSE', data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
plt.figure(figsize=(5, 10))
sns.set_theme(style='whitegrid')
ax = sns.barplot(y=predictions_train.index, x='Time Taken', data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
